# %%
import dd
import matplotlib.pyplot as plt
import numpy as np
from getsig import getsig

# %%
shotnr = 34373
ti = 1
tf = 4
tx, sx = getsig(shotnr, 'SXF', 'I_054', tBegin=ti, tEnd=tf)
tb, sb = getsig(shotnr, 'XVR', 'S1L1A07', tBegin=ti, tEnd=tf)

# %%
plt.plot(tb,sb)
plt.xlim(ti,tf)
plt.show()

# %%
tt, st = getsig(shotnr, 'BPD', 'Pradtot', tBegin=1, tEnd=5)

# %%
plt.plot(tt, st)
plt.show()

# %%
t5, s5 = getsig(shotnr, 'DCN', 'H-1')

# %%
plt.plot(t5, s5)
plt.show()
